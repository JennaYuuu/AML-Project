# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
columns = ['Model', 'Accuracy', 'ROC_AUC', 'Average_Precision', 'F1']

# %%
df_scoring = pd.DataFrame(columns = columns)
df_scoring = df_scoring.append(pd.DataFrame(data = [['Logistic', 0.924, 0.873, 0.366, 0.486]], columns=columns), ignore_index=True)
df_scoring = df_scoring.append(pd.DataFrame(data = [['Neural Network', 0.92286, 0.85144, 0.243337, 0.4017]], columns=columns), ignore_index=True)

# %%
df_scoring
# Out:
#             Model  Accuracy  Precision   ROC_AUC  Average_Precision
# 0        Logistic   0.92400    0.87300  0.366000             0.4860
# 1  Neural Network   0.92286    0.85144  0.243337             0.4017

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_scoring, x="Model", y="Accuracy", hue = 'Model')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Accuracy'>

# %%
sns.barplot(data=df_scoring, x="Model", y="Precision", hue = 'Model')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Precision'>

# %%
sns.barplot(data=df_scoring, x="Model", y="ROC_AUC", hue = 'Model')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='ROC_AUC'>

# %%
sns.barplot(data=df_scoring, x="Model", y="ROC_AUC", hue = 'Model')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='ROC_AUC'>
